# %% [markdown]
# ## Report: act_report

# %% [markdown]
# ## Table des matières
# * [Introduction](#intro)
# * [Analyse](#analyse)
# * [Visualisation](#visualisation)
# * [Conclusion](#conclusion)

# %% [markdown]
# ### Introduction<a id='intro'></a>
#
# Le présent rapport a pour objet de communiquer les observations et visualisations produites dans l’étape analyse et visualisation du projet **"Préparation et analyse de données"** . Les tableaux utilisés à cette étape sont ceux résultants du nettoyage à savoir `dogs_rating_clean` et `predictions`. `dogs_rating_clean` représente le ***master data*** et comporte les données d’archives améliorées, les données additionnelles collectées et les données sur les images utilisées pour les prédictions. Le tableau `predictions` comporte les données sur les prédictions successives des images associées à chaque tweet.
#
# ### Analyse<a id='analyse'></a>
# Mon analyse a été guidée par les questions suivantes:
# * _Quelles sont les 10 races de chiens les plus prédites ?_
# * _Quelles sont les 10 races de chiens les mieux notées ?_
# * _Quelles sont les 10 races de chiens les plus appréciées ?_
#
#
# #### Quelles sont les 10 races de chiens les plus prédites ?
#
# Le but de cette question est d’identifier les races de chiens les plus récurrentes dans les prédictions successives, en particulier le classement du top 10. Pour chaque race appartenant à ce classement je veux connaître le rang, le nombre d’occurrences et la moyenne du degré de confiance avec lequel les images ont été prédites.
#
# ![Top 10 des races de chiens prédites](attachment:top10_races_pr%C3%A9dites.png)
# **_<center>Liste du Top 10 des races de chiens les plus prédites</center>_**
#
# Le tableau qui précède montre que la race de chiens `Golden_retriever` est la plus récurrente dans les prédictions. Elle apparaît à **_267_** reprises avec une moyenne de degré de confiance moyen de **_44%_**, suivi de `Labrador_retriever`
#
# #### Quelles sont les 10 races de chiens les mieux notées ?
#
# Ici également le but est de faire un classement du top 10 des races de chiens les mieux notées. En revanche pour éviter que les résultats ne soient pas biaisés, en lieu et place de la moyenne des notes, j'ai plutôt opté pour la mesure que j'ai appelé `rating_ratio`, laquelle est le quotient du nombre d’occurrences sur les note médiane de chaque race. Avec cette mesure on obtient le classement qui suit:
#
# ![Top 10 des races les mieux notés](attachment:top10_races_not%C3%A9es.png)
# **_<center>Liste du Top 10 des races de chiens ayant obtenue les meilleures notes</center>_**
#
# On peut observer que l'ordre du classement a été conservé, à quelques exceptions près. `Golden_retriever` et `Labrador_retriever` se partagent la tête de liste avec **_12_** comme notes médianes et **_22,25_** pour rating_ratio, suivi de `Chihuahua`. Les statistiques des notes ci-dessous, des races `Golden_retriever` et `Labrador_retriever` donnent un avantage à la première race qui reçoit une note moyenne (à effecif égal), **_12,89_** vs **_12,36_**
#
# ![Statistiques des notes de Golden_retriever et Labrador_retriever](attachment:stats.png)
# **_<center>Statistiques des notes</center>_**
#
# #### Quelles sont les 10 races de chiens les plus appréciées ?
#
# Ce classement utilise le nombre total de favoris comme mesure, en tenant compte de la tendance générale à avoir une préférence pour ce qu’on apprécie. Le résultat est présenté dans le tableau qui suit:
#
# ![Top 10 des races favorites](attachment:top_10_races_favirites.png)
# **_<center>Liste du Top 10 des races de chiens ayant obtenue plus de favoris</center>_**
#
# Dans ce classement en revanche, on observe que `Labrador_retriever` qui occupait jusque-là la deuxième place passe en tête avec **_3,3M_** de favoris, suivi de `Golden_retriever` **_~3M_** de favoris. `Chesapeake_bay_retriever` n’apparaît pas dans Top 10 des races dont les prédictions ont été les plus récurrentes, mais occupe successivement la 10ème et la 9ème place dans le classement des races les mieux notées et celui des plus appréciées.
#
# ### Visualisation<a id='visualisation'></a>
#
# Dans cette rubrique j'ai utilisé le graphique à barres pour illustrer le classement du Top 10 des races de chiens les mieux notées et celui des races les plus appréciées, respectivement. Celà permet de mieux apprécier les proportions dans chaque classement.
#
# ![Top 10 des races de chiens les mieux notées et les plus appréciées](attachment:analyse.png)
# **_<center>Top 10 des races de chiens les mieux notées et les plus appréciées</center>_**
#
#
#
# ### Conclusion<a id='conclusion'></a>
#
# Les observations faites dans notre analyse ainsi que la visualisation produite peuvent nous renseigner sur la tendance générale en matière de préférence de races de chiens chez les personnes et peuvent probablement orienter à l'adoption d'une race ou d'une autre de chiens.
